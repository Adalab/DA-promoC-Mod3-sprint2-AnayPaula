# %%
import pandas as pd

# %%
df_queso=pd.read_clipboard()

# %%
df_ciguenas=pd.read_clipboard()
df_ciguenas
# Out:
#       Provincia    2004      Área   (km2) parejas/100   km2 parejas/100.1  \
# 0          2004    1994  1984.000    None        None  None          None
# 1             A  CORUÑA     2.000   7.999        0,03  0,00          0,00
# 2         ÁLAVA      32     3.047    1,05        0,23  0,03          None
# 3      ALBACETE       1    14.916    0,01        0,00  0,00          None
# 4      ASTURIAS       1    10.565    0,01        0,00  0,00          None
# 5         ÁVILA   1.261     8.048   15,67        5,48  2,34          None
# 6       BADAJOZ   4.155    21.647   19,19       14,38  6,16          None
# 7        BURGOS     383    14.329    2,67        0,98  0,54          None
# 8       CÁCERES   7.035    19.945   35,27       22,04  8,47          None
# 9         CÁDIZ     692     7.385    9,37        3,86  2,76          None
# 10    CANTABRIA     177     5.289    3,35        1,49  0,49          None
# 11       CIUDAD    REAL     1.493  19.748        7,56  3,25          1,35
# ...

# %%
df_nidos=pd.read_clipboard()

# %%
df_nidos
# Out:
#               A     CORUÑA     -   -.1    -.2      -.3       2   0,00
# 0         ÁLAVA       2,03  2,10  2,24     32   32.000  100,00   None
# 1      ALBACETE          -     -     -      -    1.000    0,00   None
# 2      ASTURIAS          -     -     -      -    1.000    0,00   None
# 3         ÁVILA       2,13  2,14  2,18    240    1.261   19,03   None
# 4       BADAJOZ       1,88  1,91  2,41    149    4.155    3,59   None
# 5        BURGOS       1,92  2,00  2,14     53  383.000   13,84   None
# 6       CÁCERES       1,88  1,89  2,31    910    7.035   12,94   None
# 7         CÁDIZ       1,73  1,75  2,24     70  692.000   10,12   None
# 8     CANTABRIA       1,52  1,59  2,28    177  177.000  100,00   None
# 9        CIUDAD       REAL  1,08  1,22   1,31  610.000   1.493  40,86
# 10      CÓRDOBA       1,42  1,75  1,87     64  391.000   16,37   None
# 11       GIRONA       1,91  2,12  2,64     56   56.000  100,00   None
# ...

# %%
df_nidos.to_csv('files/nidos.csv')

# %%
df_ciguenas.to_csv('files/ciguenas.csv')

# %%
df_queso.to_csv('files/muertes_y_queso.csv')
