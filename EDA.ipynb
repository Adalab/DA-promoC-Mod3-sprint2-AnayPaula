# %%
# tratamiento de los datos
# ============================================
import pandas as pd
import numpy as np
pd.options.display.max_columns = None

# librerías para la visualización de los datos
# ============================================
import matplotlib.pyplot as plt
import seaborn as sns

# Establecer tamaño fijo de gráficas
# ==================================
plt.rcParams["figure.figsize"] = (10,8)

# Configuración warnings
# ======================
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# https://www.kaggle.com/datasets/catherinerasgaitis/mxmh-survey-results

# %%
df = pd.read_csv('datos/mxmh_survey_results.csv')
df.head()
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   Foreign languages    BPM Frequency [Classical] Frequency [Country]  \
# 0               Yes  156.0                Rarely               Never
# 1                No  119.0             Sometimes               Never
# 2               Yes  132.0                 Never               Never
# 3               Yes   84.0             Sometimes               Never
# 4                No  107.0                 Never               Never
#
#    Frequency [EDM] Frequency [Folk] Frequency [Gospel] Frequency [Hip hop]  \
# 0           Rarely            Never              Never           Sometimes
# 1            Never           Rarely          Sometimes              Rarely
# 2  Very frequently            Never              Never              Rarely
# 3            Never           Rarely          Sometimes               Never
# 4           Rarely            Never             Rarely     Very frequently
#
#   Frequency [Jazz] Frequency [K pop] Frequency [Latin] Frequency [Lofi]  \
# 0            Never   Very frequently   Very frequently           Rarely
# 1  Very frequently            Rarely         Sometimes           Rarely
# 2           Rarely   Very frequently             Never        Sometimes
# 3  Very frequently         Sometimes   Very frequently        Sometimes
# 4            Never   Very frequently         Sometimes        Sometimes
#
#   Frequency [Metal]  Frequency [Pop]  Frequency [R&B]  Frequency [Rap]  \
# 0             Never  Very frequently        Sometimes  Very frequently
# 1             Never        Sometimes        Sometimes           Rarely
# 2         Sometimes           Rarely            Never           Rarely
# 3             Never        Sometimes        Sometimes            Never
# 4             Never        Sometimes  Very frequently  Very frequently
#
#   Frequency [Rock] Frequency [Video game music]  Anxiety  Depression  \
# 0            Never                    Sometimes      3.0         0.0
# 1  Very frequently                       Rarely      7.0         2.0
# 2           Rarely              Very frequently      7.0         7.0
# 3            Never                        Never      9.0         7.0
# 4            Never                       Rarely      7.0         2.0
#
#    Insomnia  OCD Music effects    Permissions
# 0       1.0  0.0           NaN  I understand.
# 1       2.0  1.0           NaN  I understand.
# 2      10.0  2.0     No effect  I understand.
# 3       3.0  3.0       Improve  I understand.
# 4       5.0  9.0       Improve  I understand.

# %%
df.isnull().sum()
# Out:
# Timestamp                         0
# Age                               1
# Primary streaming service         1
# Hours per day                     0
# While working                     3
# Instrumentalist                   4
# Composer                          1
# Fav genre                         0
# Exploratory                       0
# Foreign languages                 4
# BPM                             107
# Frequency [Classical]             0
# Frequency [Country]               0
# Frequency [EDM]                   0
# Frequency [Folk]                  0
# Frequency [Gospel]                0
# Frequency [Hip hop]               0
# Frequency [Jazz]                  0
# Frequency [K pop]                 0
# Frequency [Latin]                 0
# Frequency [Lofi]                  0
# Frequency [Metal]                 0
# Frequency [Pop]                   0
# Frequency [R&B]                   0
# Frequency [Rap]                   0
# Frequency [Rock]                  0
# Frequency [Video game music]      0
# Anxiety                           0
# Depression                        0
# Insomnia                          0
# OCD                               0
# Music effects                     8
# Permissions                       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Timestamp                     736 non-null    object
#  1   Age                           735 non-null    float64
#  2   Primary streaming service     735 non-null    object
#  3   Hours per day                 736 non-null    float64
#  4   While working                 733 non-null    object
#  5   Instrumentalist               732 non-null    object
#  6   Composer                      735 non-null    object
#  7   Fav genre                     736 non-null    object
#  8   Exploratory                   736 non-null    object
#  9   Foreign languages             732 non-null    object
#  10  BPM                           629 non-null    float64
#  11  Frequency [Classical]         736 non-null    object
#  12  Frequency [Country]           736 non-null    object
#  13  Frequency [EDM]               736 non-null    object
#  14  Frequency [Folk]              736 non-null    object
#  15  Frequency [Gospel]            736 non-null    object
#  16  Frequency [Hip hop]           736 non-null    object
#  17  Frequency [Jazz]              736 non-null    object
#  18  Frequency [K pop]             736 non-null    object
#  19  Frequency [Latin]             736 non-null    object
#  20  Frequency [Lofi]              736 non-null    object
#  21  Frequency [Metal]             736 non-null    object
#  22  Frequency [Pop]               736 non-null    object
#  23  Frequency [R&B]               736 non-null    object
#  24  Frequency [Rap]               736 non-null    object
#  25  Frequency [Rock]              736 non-null    object
#  26  Frequency [Video game music]  736 non-null    object
#  27  Anxiety                       736 non-null    float64
#  28  Depression                    736 non-null    float64
#  29  Insomnia                      736 non-null    float64
#  30  OCD                           736 non-null    float64
#  31  Music effects                 728 non-null    object
#  32  Permissions                   736 non-null    object
# dtypes: float64(7), object(26)
# memory usage: 189.9+ KB

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Primary streaming service', 'Hours per day',
#        'While working', 'Instrumentalist', 'Composer', 'Fav genre',
#        'Exploratory', 'Foreign languages', 'BPM', 'Frequency [Classical]',
#        'Frequency [Country]', 'Frequency [EDM]', 'Frequency [Folk]',
#        'Frequency [Gospel]', 'Frequency [Hip hop]', 'Frequency [Jazz]',
#        'Frequency [K pop]', 'Frequency [Latin]', 'Frequency [Lofi]',
#        'Frequency [Metal]', 'Frequency [Pop]', 'Frequency [R&B]',
#        'Frequency [Rap]', 'Frequency [Rock]', 'Frequency [Video game music]',
#        'Anxiety', 'Depression', 'Insomnia', 'OCD', 'Music effects',
#        'Permissions'],
#       dtype='object')

# %%
df[(df['Anxiety']== 0)] #& (df['Depression'] == 0 ) & (df['Insomnia']== 0) & (df['OCD'] == 0 )]
# Out:
#                Timestamp   Age          Primary streaming service  \
# 34    8/28/2022 11:08:51  16.0                            Spotify
# 50    8/28/2022 12:37:17  17.0                        Apple Music
# 55    8/28/2022 13:01:42  16.0                        Apple Music
# 66    8/28/2022 13:46:03  24.0                            Spotify
# 96    8/28/2022 15:02:14  20.0                            Spotify
# 138   8/28/2022 18:03:27  16.0                      YouTube Music
# 143   8/28/2022 18:17:00  53.0                            Spotify
# 144   8/28/2022 18:17:46  25.0                            Spotify
# 161   8/28/2022 18:59:40  18.0            Other streaming service
# 171   8/28/2022 19:22:30  19.0                      YouTube Music
# 236   8/28/2022 22:49:17  27.0                            Spotify
# 248   8/28/2022 23:34:19  20.0                            Spotify
# 262    8/29/2022 0:33:49  21.0                            Spotify
# 271    8/29/2022 1:06:46  19.0            Other streaming service
# 289    8/29/2022 2:43:40  40.0            Other streaming service
# 310    8/29/2022 4:36:16  49.0                            Spotify
# 315    8/29/2022 4:53:44  17.0                            Spotify
# 384   8/29/2022 17:58:47  12.0                      YouTube Music
# 405   8/29/2022 22:04:50  23.0                            Spotify
# 428   8/30/2022 17:43:36  72.0                            Spotify
# 465    9/1/2022 15:50:14  16.0                            Spotify
# 474    9/1/2022 16:58:12  58.0                      YouTube Music
# 522     9/2/2022 8:05:59  60.0                            Spotify
# 529    9/2/2022 15:24:02  56.0            Other streaming service
# 537     9/3/2022 3:54:07  50.0  I do not use a streaming service.
# 541    9/3/2022 10:20:18  20.0                            Spotify
# 551    9/3/2022 17:14:57  34.0                            Spotify
# 586    9/6/2022 14:43:07  23.0  I do not use a streaming service.
# 598    9/8/2022 19:16:43  17.0                            Spotify
# 599    9/8/2022 21:30:13  18.0                            Spotify
# 603    9/9/2022 11:15:23  46.0  I do not use a streaming service.
# 606    9/9/2022 22:31:31  21.0                            Spotify
# 607    9/9/2022 23:34:31  19.0  I do not use a streaming service.
# 695   9/28/2022 17:25:48  89.0                            Spotify
# 727  10/26/2022 19:45:54  26.0                      YouTube Music
#
#      Hours per day While working Instrumentalist Composer         Fav genre  \
# 34             1.0           Yes              No       No         Classical
# 50             2.0           Yes             Yes       No               EDM
# 55             2.0           Yes             Yes       No         Classical
# 66             3.0            No              No       No              Rock
# 96             3.0            No              No      Yes               EDM
# 138            3.0           Yes              No      Yes               Pop
# 143            7.0           Yes              No       No               Pop
# 144            1.0           Yes              No       No               EDM
# 161            2.0           Yes              No       No             K pop
# 171            5.0           Yes              No       No             Metal
# 236            5.0           Yes              No      Yes              Folk
# 248            2.0            No             Yes      Yes             Metal
# 262            3.0           Yes              No       No           Country
# 271            5.0           Yes              No       No               EDM
# 289            3.0           Yes              No       No              Rock
# 310            2.0           Yes              No       No              Folk
# 315            2.0           Yes              No       No              Rock
# 384            2.0           Yes             Yes      Yes         Classical
# 405            2.0           Yes             Yes       No              Rock
# 428            6.0           Yes             Yes      Yes              Rock
# 465           10.0            No              No       No              Rock
# 474            1.0           Yes             Yes      Yes         Classical
# 522            2.0           Yes              No       No              Rock
# 529            2.0            No              No       No              Jazz
# 537            1.0            No              No       No              Rock
# 541            1.5           Yes              No       No           Country
# 551            3.0           Yes              No       No         Classical
# 586           10.0           Yes             Yes      Yes             Metal
# 598           12.0           Yes             Yes       No             Latin
# 599            6.0           Yes              No       No               EDM
# 603            1.0            No              No       No              Rock
# 606            1.0           Yes              No       No  Video game music
# 607            0.0            No              No       No         Classical
# 695           24.0           Yes             Yes      Yes               Rap
# 727            1.0           Yes              No       No             Metal
#
#     Exploratory Foreign languages    BPM Frequency [Classical]  \
# 34           No                No   75.0       Very frequently
# 50          Yes                No  128.0                 Never
# 55          Yes                No    NaN       Very frequently
# 66          Yes               Yes  130.0             Sometimes
# 96          Yes               Yes  121.0                Rarely
# 138          No                No    NaN                Rarely
# 143         Yes               Yes   92.0       Very frequently
# 144          No                No  107.0                 Never
# 161          No               Yes  122.0                Rarely
# 171          No               Yes  136.0             Sometimes
# 236         Yes               Yes  140.0                Rarely
# 248          No               Yes  220.0                Rarely
# 262         Yes                No  108.0                Rarely
# 271         Yes               Yes   97.0                Rarely
# 289         Yes               Yes  178.0             Sometimes
# 310         Yes                No  147.0                Rarely
# 315         Yes               Yes   93.0                 Never
# 384          No                No    NaN       Very frequently
# 405         Yes               Yes  141.0                Rarely
# 428          No                No   77.0                 Never
# 465         Yes                No  105.0                Rarely
# 474         Yes                No   80.0             Sometimes
# 522          No                No    NaN                Rarely
# 529         Yes               Yes  120.0             Sometimes
# 537          No                No   98.0             Sometimes
# 541          No                No    NaN                Rarely
# 551          No               Yes   95.0       Very frequently
# 586          No               Yes  165.0                 Never
# 598         Yes                No  172.0       Very frequently
# 599         Yes               Yes   90.0                Rarely
# 603          No                No  120.0                 Never
# 606         Yes               Yes    NaN       Very frequently
# 607         Yes               Yes    NaN       Very frequently
# 695          No                No  143.0                 Never
# 727         Yes               Yes  136.0             Sometimes
#
#     Frequency [Country]  Frequency [EDM] Frequency [Folk] Frequency [Gospel]  \
# 34                Never            Never           Rarely              Never
# 50               Rarely  Very frequently            Never              Never
# 55                Never            Never            Never              Never
# 66            Sometimes            Never           Rarely              Never
# 96            Sometimes  Very frequently            Never              Never
# 138           Sometimes        Sometimes            Never              Never
# 143           Sometimes  Very frequently           Rarely             Rarely
# 144               Never  Very frequently            Never              Never
# 161               Never            Never            Never              Never
# 171              Rarely           Rarely        Sometimes          Sometimes
# 236               Never        Sometimes  Very frequently          Sometimes
# 248               Never            Never            Never              Never
# 262     Very frequently            Never        Sometimes             Rarely
# 271               Never  Very frequently        Sometimes              Never
# 289               Never            Never            Never              Never
# 310              Rarely        Sometimes  Very frequently              Never
# 315              Rarely        Sometimes        Sometimes             Rarely
# 384               Never            Never            Never              Never
# 405              Rarely            Never  Very frequently              Never
# 428           Sometimes            Never            Never              Never
# 465     Very frequently            Never  Very frequently             Rarely
# 474              Rarely            Never           Rarely          Sometimes
# 522              Rarely            Never           Rarely             Rarely
# 529               Never        Sometimes        Sometimes             Rarely
# 537           Sometimes            Never            Never              Never
# 541     Very frequently        Sometimes            Never              Never
# 551               Never            Never            Never              Never
# 586               Never            Never            Never              Never
# 598               Never           Rarely           Rarely          Sometimes
# 599               Never  Very frequently            Never              Never
# 603           Sometimes            Never            Never              Never
# 606     Very frequently           Rarely        Sometimes             Rarely
# 607              Rarely        Sometimes           Rarely             Rarely
# 695               Never           Rarely           Rarely              Never
# 727              Rarely        Sometimes  Very frequently              Never
#
#     Frequency [Hip hop] Frequency [Jazz] Frequency [K pop] Frequency [Latin]  \
# 34                Never            Never             Never             Never
# 50               Rarely            Never             Never            Rarely
# 55               Rarely        Sometimes             Never             Never
# 66                Never           Rarely             Never            Rarely
# 96            Sometimes            Never            Rarely             Never
# 138              Rarely            Never         Sometimes             Never
# 143           Sometimes        Sometimes            Rarely         Sometimes
# 144              Rarely            Never            Rarely             Never
# 161               Never            Never   Very frequently             Never
# 171           Sometimes           Rarely             Never             Never
# 236              Rarely           Rarely         Sometimes         Sometimes
# 248               Never           Rarely             Never             Never
# 262              Rarely            Never             Never             Never
# 271           Sometimes           Rarely             Never         Sometimes
# 289               Never           Rarely             Never             Never
# 310           Sometimes           Rarely             Never             Never
# 315              Rarely        Sometimes            Rarely            Rarely
# 384               Never            Never             Never             Never
# 405              Rarely            Never             Never             Never
# 428               Never  Very frequently             Never         Sometimes
# 465              Rarely        Sometimes             Never             Never
# 474              Rarely        Sometimes            Rarely            Rarely
# 522               Never           Rarely             Never             Never
# 529               Never  Very frequently             Never            Rarely
# 537     Very frequently        Sometimes            Rarely            Rarely
# 541           Sometimes        Sometimes         Sometimes            Rarely
# 551               Never           Rarely             Never             Never
# 586               Never            Never             Never             Never
# 598     Very frequently            Never            Rarely   Very frequently
# 599           Sometimes           Rarely   Very frequently   Very frequently
# 603               Never            Never             Never             Never
# 606           Sometimes        Sometimes             Never             Never
# 607           Sometimes           Rarely            Rarely            Rarely
# 695     Very frequently        Sometimes             Never             Never
# 727               Never           Rarely             Never             Never
#
#     Frequency [Lofi] Frequency [Metal]  Frequency [Pop]  Frequency [R&B]  \
# 34             Never            Rarely            Never            Never
# 50            Rarely   Very frequently        Sometimes        Sometimes
# 55             Never             Never           Rarely           Rarely
# 66             Never   Very frequently  Very frequently            Never
# 96         Sometimes             Never        Sometimes            Never
# 138        Sometimes             Never  Very frequently            Never
# 143           Rarely            Rarely  Very frequently  Very frequently
# 144           Rarely             Never            Never            Never
# 161           Rarely             Never  Very frequently        Sometimes
# 171  Very frequently   Very frequently            Never            Never
# 236  Very frequently         Sometimes  Very frequently        Sometimes
# 248            Never   Very frequently            Never            Never
# 262            Never            Rarely        Sometimes            Never
# 271  Very frequently   Very frequently           Rarely            Never
# 289           Rarely         Sometimes        Sometimes           Rarely
# 310        Sometimes            Rarely        Sometimes        Sometimes
# 315           Rarely   Very frequently  Very frequently        Sometimes
# 384           Rarely             Never           Rarely            Never
# 405  Very frequently   Very frequently  Very frequently            Never
# 428            Never             Never           Rarely  Very frequently
# 465            Never   Very frequently        Sometimes           Rarely
# 474            Never             Never           Rarely            Never
# 522            Never            Rarely        Sometimes        Sometimes
# 529           Rarely            Rarely        Sometimes           Rarely
# 537            Never            Rarely  Very frequently        Sometimes
# 541            Never             Never        Sometimes            Never
# 551           Rarely         Sometimes           Rarely            Never
# 586            Never   Very frequently            Never            Never
# 598           Rarely         Sometimes           Rarely            Never
# 599  Very frequently             Never  Very frequently  Very frequently
# 603            Never             Never        Sometimes            Never
# 606  Very frequently            Rarely        Sometimes            Never
# 607           Rarely             Never           Rarely           Rarely
# 695           Rarely            Rarely           Rarely        Sometimes
# 727           Rarely   Very frequently           Rarely            Never
#
#      Frequency [Rap] Frequency [Rock] Frequency [Video game music]  Anxiety  \
# 34             Never            Never                       Rarely      0.0
# 50         Sometimes  Very frequently                       Rarely      0.0
# 55            Rarely        Sometimes                       Rarely      0.0
# 66             Never  Very frequently                        Never      0.0
# 96         Sometimes        Sometimes                       Rarely      0.0
# 138           Rarely  Very frequently                       Rarely      0.0
# 143           Rarely  Very frequently                       Rarely      0.0
# 144            Never           Rarely                       Rarely      0.0
# 161            Never            Never                        Never      0.0
# 171        Sometimes  Very frequently                    Sometimes      0.0
# 236            Never  Very frequently              Very frequently      0.0
# 248           Rarely        Sometimes                       Rarely      0.0
# 262            Never  Very frequently                    Sometimes      0.0
# 271  Very frequently        Sometimes                       Rarely      0.0
# 289            Never        Sometimes                        Never      0.0
# 310        Sometimes           Rarely                       Rarely      0.0
# 315        Sometimes  Very frequently                    Sometimes      0.0
# 384            Never            Never                        Never      0.0
# 405        Sometimes  Very frequently              Very frequently      0.0
# 428            Never  Very frequently                        Never      0.0
# 465           Rarely  Very frequently                        Never      0.0
# 474            Never            Never                        Never      0.0
# 522            Never  Very frequently                        Never      0.0
# 529            Never        Sometimes                       Rarely      0.0
# 537        Sometimes  Very frequently                        Never      0.0
# 541        Sometimes        Sometimes                        Never      0.0
# 551            Never        Sometimes                    Sometimes      0.0
# 586            Never        Sometimes                        Never      0.0
# 598  Very frequently  Very frequently                    Sometimes      0.0
# 599  Very frequently           Rarely                    Sometimes      0.0
# 603            Never        Sometimes                        Never      0.0
# 606        Sometimes        Sometimes              Very frequently      0.0
# 607           Rarely           Rarely                       Rarely      0.0
# 695  Very frequently           Rarely                        Never      0.0
# 727            Never            Never                       Rarely      0.0
#
#      Depression  Insomnia  OCD Music effects    Permissions
# 34          0.0       0.0  0.0     No effect  I understand.
# 50          0.0       0.0  0.0       Improve  I understand.
# 55          0.0       1.0  3.0       Improve  I understand.
# 66          0.0       8.0  0.0     No effect  I understand.
# 96          3.0       7.0  0.0       Improve  I understand.
# 138         0.0       4.0  0.0     No effect  I understand.
# 143         0.0       0.0  0.0       Improve  I understand.
# 144         8.0       0.0  0.0       Improve  I understand.
# 161         2.0       0.0  0.0           NaN  I understand.
# 171         5.0       1.0  0.0     No effect  I understand.
# 236         9.0       4.0  0.0       Improve  I understand.
# 248         0.0       0.0  1.0     No effect  I understand.
# 262         8.0       0.0  5.0       Improve  I understand.
# 271         1.0       3.0  5.0       Improve  I understand.
# 289         4.0       4.0  0.0       Improve  I understand.
# 310         0.0       2.0  0.0     No effect  I understand.
# 315         8.0       0.0  0.0       Improve  I understand.
# 384         0.0       3.0  0.0       Improve  I understand.
# 405         5.0       7.0  0.0     No effect  I understand.
# 428         1.0       0.0  2.0       Improve  I understand.
# 465         0.0       0.0  0.0     No effect  I understand.
# 474         0.0       2.0  1.0       Improve  I understand.
# 522         0.0       0.0  0.0       Improve  I understand.
# 529         0.0       0.0  5.0     No effect  I understand.
# 537         0.0       7.0  0.0       Improve  I understand.
# 541         2.0       0.0  1.0       Improve  I understand.
# 551         0.0       0.0  0.0     No effect  I understand.
# 586         0.0       0.0  0.0     No effect  I understand.
# 598         3.0       9.0  5.0     No effect  I understand.
# 599         2.0       1.0  5.0       Improve  I understand.
# 603         0.0       1.0  0.0     No effect  I understand.
# 606         6.0       0.0  4.0       Improve  I understand.
# 607         0.0       0.0  0.0       Improve  I understand.
# 695         0.0       0.0  0.0     No effect  I understand.
# 727         0.0       0.0  0.0     No effect  I understand.

# %%
df['Fav genre'].value_counts()
# Out:
# Rock                188
# Pop                 114
# Metal                88
# Classical            53
# Video game music     44
# EDM                  37
# R&B                  35
# Hip hop              35
# Folk                 30
# K pop                26
# Country              25
# Rap                  22
# Jazz                 20
# Lofi                 10
# Gospel                6
# Latin                 3
# Name: Fav genre, dtype: int64
